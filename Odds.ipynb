# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd
# import csv
# import time

# #playerList = pd.read_csv("CleanedPlayers.csv")
# url = 'https://sportsbook.draftkings.com/nba-player-props?wpsrc=Organic%20Search&wpaffn=Google&wpkw=https%3A%2F%2Fsportsbook.draftkings.com%2Fnba-player-props&wpcn=nba-player-props'
# seasonYear = ['/gamelog/2024/']#, '/gamelog/2020/', '/gamelog/2019/']

# f = open('latestDataPull6.csv', 'w', newline= '')
# scrapedGames = csv.writer(f)
# statList = []
# headerCount = 0

# for x in range(0, 522):
#     url_extension = playerList['ID'].iloc[x]
#     playerName = playerList['Name'].iloc[x]
    
#     for y in seasonYear:
        

#         r= requests.get(url + url_extension + y)

#         rPlayer = requests.get(url + url_extension + ".html")


#         soup = BeautifulSoup(r.text, 'html.parser')

#         psoup = BeautifulSoup(rPlayer.text, 'html.parser')


        
#         season_table = soup.find('table' , id = "sportsbook-table")
#         #player_table = psoup.find('table' , id = "per_game")
#         time.sleep(5)

#         playerPerGame = pd.read_html(url + url_extension + ".html")
#         time.sleep(5)
#         statList = []
#         headerCount = 0
#         print(url + url_extension + y)
#         print(url + url_extension + ".html")
#         print(playerPerGame[1])
#         ptable = playerPerGame[1]
#         print(len(ptable.columns))
#         if(len(ptable.columns) < 4):
#             continue
#         idx = ptable.index[ptable['Season'] == 'Career'].tolist()[0]-1
#         print(idx)
#         minPlayed = ptable['MP'].iloc[idx]
#         print(minPlayed)

#         try:
#             for headers in player_table.find_all('th'):
                    

#                     pvalueHeader = headers.text
#                     if pvalueHeader == 'MP':
                        
#                         if(float(minPlayed) >= 10):
#                             try:
#                                 for headers in season_table.find_all('th'):
#                                     valueHeader = headers.text
#                                     if valueHeader == 'Rk':
#                                         headerCount = 1

#                                     if headerCount == 1:
#                                         statList.append(valueHeader)
#                                 scrapedGames.writerow(statList)
#                                 gameArray = []
#                                 breakValue = 0

#                                 for game in season_table.find_all('tr'):
#                                     cols = game.find_all('td')
#                                     statList = [playerName]

#                                     for col in cols:
#                                         if 'Upcoming' in col.text:
#                                             breakValue = 1
#                                             break
#                                         else:
#                                             stat_col = col.text
#                                             statList.append(stat_col)
#                                         if breakValue == 1:
#                                             break
                                        
#                                     scrapedGames.writerow(statList)
#                                     gameArray.append(statList)
                                        


#                             except:
#                                 continue

#         except:
#             continue

# %%
 #Cwsdtn9Zrw7iX2XzE26x7T4fs3rhDMHC4upuuh2Bs
import requests
import urllib
from datetime import datetime

BASE_URL = 'https://api.prop-odds.com'
API_KEY = 'Cwsdtn9Zrw7iX2XzE26x7T4fs3rhDMHC4upuuh2Bs'


def get_request(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()

    print('Request failed with status:', response.status_code)
    return {}


def get_nba_games():
    now = datetime.now()
    query_params = {
        'date': now.strftime('%Y-%m-%d'),
        'tz': 'America/New_York',
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/games/nba?' + params
    return get_request(url)


def get_game_info(game_id):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/game/' + game_id + '?' + params
    return get_request(url)


def get_markets(game_id):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/markets/' + game_id + '?' + params
    return get_request(url)


def get_most_recent_point_odds(game_id, market):
    query_params = {
        'api_key': API_KEY,
    }
    params = urllib.parse.urlencode(query_params)
    url = BASE_URL + '/beta/odds/' + game_id + '/' + market + '?' + params
    return get_request(url)


def main():
    game_ids = []
    markets = []
    games = get_nba_games()
    if len(games['games']) == 0:
        print('No games scheduled for today.')
        return

    first_game = games['games'][0]
    for i in range(len(games)):
        game_ids.append(games['games'][i])
    print(game_ids)
    # print(first_game)
    #game_info = get_game_info(game_id)
    # print(game_info)

    for i in game_ids:
        markets.append(get_markets(i['game_id']))

    # if len(markets['markets']) == 0:
    #     print('No markets found.')
    #     return

    points_odds = []
    for i in range(len(markets)):
        market = markets[i]['markets']
        points_odds.append(get_most_recent_point_odds(markets[i]['game_id'], 'player_points_over_under'))	 #market[i]['name']))

    print(points_odds)


    #make for loop that only adds the standard lines
    # print(first_market)
    #player_points_over_under	
    #print(odds)


if __name__ == '__main__':
    main()
# Out:
# [{'game_id': '9323404284863080d81fd84ff3ee31d9', 'away_team': 'Minnesota Timberwolves', 'home_team': 'Boston Celtics', 'start_timestamp': '2024-01-11T00:00:00Z', 'participants': []}, {'game_id': '766d51c0d43e2d79ce92446af745375e', 'away_team': 'Sacramento Kings', 'home_team': 'Charlotte Hornets', 'start_timestamp': '2024-01-11T00:00:00Z', 'participants': []}, {'game_id': 'ac1181b997937119e339b249dd1b5658', 'away_team': 'San Antonio Spurs', 'home_team': 'Detroit Pistons', 'start_timestamp': '2024-01-11T00:00:00Z', 'participants': []}]
# ...

# %%
get_nba_games()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_nba_games()
#
# NameError: name 'get_nba_games' is not defined
